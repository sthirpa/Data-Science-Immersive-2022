# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Analyzing ACT and SAT test scores of high school seniors in all the US states from the years 2018 and 2019, this paper will recommend how test participation rates in some states.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# This analysis is made depending on two databases: sat_2018.csv: 2018 SAT Scores by State, and sat_2019.csv: 2019 SAT Scores by State.
# Both datasets contain participation rates, evidence based reading and writing, and maths score columns with their corresponding total test scores.

# %% [markdown]
# It's unclear whether it's due to the covid19 pandemic or not, it seems the US is suspending the standardized test(SAT and ACT) sincethe beginning of 2020. According to [Georgetown University | The Feed](https://feed.georgetown.edu/access-affordability/most-u-s-colleges-have-dropped-act-sat-requirement-for-fall-2021-admission/), more than 1,240 of the nation's 2,330 bachelor's degree-granting schools have suspended the requirements of the tests.
#
# In California, the standardized test requirement (SAT and ACT) is suspended since April 1, 2020:
# >“UC will suspend the standardized test requirement (SAT and ACT) for students applying for fall 2021 freshman admission. This modification is not intended as an admissions policy shift but is rather a temporary accommodation driven by the current extraordinary circumstances.”
# Read more [source](https://www.insight-education.net/new-uc-and-csu-testing-update-2022/).
#
# And according to [Los Angeles Times](https://www.latimes.com/california/story/2021-10-12/more-california-colleges-remove-sat-act-score-requirements), nearly more than 130 colleges and universities in California suspended the requirement and so, the grades students earn in high school are the most important factor in higher educations admission decisions.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Evaluates mean without importing any math module library
lst = [2,3,4,5,6,7]

def mean(lst):
    total = 0
    for num in lst:
        total += int(num)
    return total/len(lst)

mean(lst)
# Out:
# 4.5

# %%
# Code: Another method tried

def mean_calculator(nums):
    total = 0
    for i in range(1,101):
        total += i
        𝜇 = total/len(range(1,101))
    return 𝜇
mean_calculator(nums = range(1,101))
# Out:
# 50.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Evaluates standard deviation without module import

lst = [2,3,4,5,6,7]
def standarddev(lst):
    devlst = []
    for num in lst:
        dev = (num - mean(lst))**2
        devlst.append(dev)
    stdev = (sum(devlst)/len(lst))**0.5 # n = len(lst)
    return stdev
standarddev(lst)
# Out:
# 1.707825127659933

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
#Code1 adopted from from Google, Chegg 
#function takes string as input
def my_function(number):
    # remove '%' symbol in number
    number = number[:-1]
    # convert into decimal approximation
    # by diving with 100
    percent = (float(number))/100
    # return decimal appropriation
    return percent

# call the function and print output 
# change string as per requirement
print(my_function('30.5%'))
# Out:
# 0.305

# %%
# Code: adopted from 'a-oh'
def p_to_d(percent):     
    keep = '0123456789.'
    new = ''
    for p in percent:
        if p in keep:
            new = new + p
    try:
        return float(new)/100
    except (ValueError, NameError, AttributeError):
        return None

p_to_d('30.5%')
# Out:
# 0.305

# %%
my_function('5%')
# Out:
# 0.05

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np # -------------- Array operations
import seaborn as sns # ----------- Data visualization
import matplotlib.pyplot as plt #  Data visualization
import pandas as pd # ----------- Importing data
import scipy.stats as stats # --- Statistical analysis

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:

# %%
# loading the datasets
act_18 = pd.read_csv('data/act_2018.csv')
act_19 = pd.read_csv('data/act_2019.csv')
sat_18 = pd.read_csv('data/sat_2018.csv')
sat_19 = pd.read_csv('data/sat_2019.csv')

# %%
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
display('Top 5 rows'.center(20, '='))
display('ACT 2018 top 5 rows: ', act_18.head())
display('ACT 2019 top 5 rows: ', act_19.head())
display('SAT 2018 top 5 rows: ', sat_18.head())
display('SAT 2019 top 5 rows: ', sat_19.head())
# Out:
# '=====Top 5 rows====='
# 'ACT 2018 top 5 rows: '
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
# 'ACT 2019 top 5 rows: '
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
# 'SAT 2018 top 5 rows: '
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# ...

# %%
# 2. Check for missing values.
act_18.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act_19.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat_18.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat_19.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# - No missing value from each dataset

# %%
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
act_18.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_19.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
sat_18.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %% [markdown]
# What did you learn?
#
# Do any of them seem odd?
# Which ones are not as they should be? <br>
# **Answer:** <br>
# Participation is easier to work with if it were a float. It is classified as an object due to the "%" sign.

# %%
# 4. Fix any errors you identified in steps 2-3.
"""
Based on what you discovered above, 
use appropriate methods to re-type incorrectly typed data.

Define a function that will allow you to convert participation 
rates to an appropriate numeric type. Use map or apply to 
change these columns in each dataframe.
"""

def convert_type(x):
    x = x.strip('%')
    x = float(x)
    return x

# %%
# or
def change_type(x):
    x = float(x.strip('%'))
    return x

# %% [markdown]
# Now, fix any individual values preventing other columns from being the appropriate type.

# %%
act_18['Participation'] = act_18['Participation'].map(change_type)
act_19['Participation'] = act_19['Participation'].map(change_type)
sat_18['Participation'] = sat_18['Participation'].map(change_type)

# %%
sat_19['Participation Rate']
# Out:
# 0       7%
# 1      41%
# 2      31%
# 3       6%
# 4      63%
# 5     100%
# 6     100%
# 7     100%
# 8      94%
# 9     100%
# 10     71%
# 11     54%
# 12    100%
# 13    100%
# 14     66%
# 15      3%
# 16      4%
# 17      4%
# 18      5%
# 19     99%
# 20     82%
# 21     81%
# 22    100%
# 23      4%
# 24      3%
# 25      4%
# 26      9%
# 27      3%
# 28     20%
# 29     95%
# 30     82%
# 31     18%
# 32     79%
# 33     51%
# 34      2%
# 35     19%
# 36     22%
# 37     51%
# 38     70%
# 39       —
# 40    100%
# 41     68%
# 42      3%
# 43      7%
# 44     68%
# 45      4%
# 46     66%
# 47       —
# 48     68%
# 49     70%
# 50     99%
# 51      3%
# 52      3%
# Name: Participation Rate, dtype: object

# %% [markdown]
# * `Rows` 39 and 47 have `corrupt or invalid` input format:

# %%
# If it's a very long list, we can sort it!
sorted(list(sat_19['Participation Rate'].unique()), reverse=True)[0:5]
# Out:
# ['—', '99%', '95%', '94%', '9%']

# %% [markdown]
# * **Here we need to deal with the `_` input**.
#
# * Let's see the minimum and maximum values:

# %%
# A = sat_19['Participation Rate']
# for n in A:
#     if n == '_':
#         pass
#     else:
#         print(my_function(n)) # function from above

# %%
print('MIN_MAX Values'.center(20,'*'))
print('sat_18 minimum: ', sat_18.min())
print('sat_18 maximum: ', sat_18.max())
print()
print('sat_19 minimum: ', sat_19.min())
print('sat_19 maximum: ', sat_19.max())
print()
print('act_18 minimum: ', act_18.min())
print('act_18 maximum: ', act_18.max())
print()
print('act_19 minimum: ', act_19.min())
print('act_19 maximum: ', act_19.max())
print()
# Out:
# ***MIN_MAX Values***
# sat_18 minimum:  State                                 Alabama
# Participation                             2.0
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object
# sat_18 maximum:  State                                 Wyoming
# Participation                           100.0
# Evidence-Based Reading and Writing        643
# Math                                      655
# Total                                    1298
# dtype: object
#
# sat_19 minimum:  State                 Alabama
# Participation Rate       100%
# EBRW                      483
# Math                      445
# Total                     935
# dtype: object
# sat_19 maximum:  State                 Wyoming
# Participation Rate          —
# EBRW                      636
# Math                      648
# Total                    1284
# dtype: object
#
# ...

# %%
sat_19.min()
# Out:
# State                 Alabama
# Participation Rate       100%
# EBRW                      483
# Math                      445
# Total                     935
# dtype: object

# %%
sat_19.max()
# Out:
# State                 Wyoming
# Participation Rate          —
# EBRW                      636
# Math                      648
# Total                    1284
# dtype: object

# %%
# Locating index for incorrect value
sat_19.loc[39,'Participation Rate']
# Out:
# '—'

# %%
sat_19.loc[47,'Participation Rate']
# Out:
# '—'

# %%
# replace with a random number 
sat_19.loc[39,'Participation Rate'] = '1%'
sat_19.loc[47,'Participation Rate'] = '1%'

# %%
# check
sat_19.loc[39,'Participation Rate']
# Out:
# '1%'

# %%
sat_19.loc[47,'Participation Rate']
# Out:
# '1%'

# %%
# 5. Display the data types of each feature.
sat_18.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %% [markdown]
# * Here Participation Rate is `object`.

# %%
act_18.dtypes, act_19.dtypes
# Out:
# (State             object
#  Participation    float64
#  Composite        float64
#  dtype: object,
#  State             object
#  Participation    float64
#  Composite        float64
#  dtype: object)

# %% [markdown]
# * same data types for the `ACT` test

# %% [markdown]
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.

# %%
def convert_type(x):
    x = x.strip('%')
    x = float(x)
    return x

# %%
sat_18.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_19['Participation Rate'] = sat_19['Participation Rate'].map(convert_type)

# %%
sat_19.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
# Basic summary of the dataset 
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
sat_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     float64
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
display(act_18.info(), act_19.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB
# None
# None

# %%
#sat_18['Participation Rate'] = sat_18['Participation Rate'].apply(lambda x: p_to_d(x))
sat_18.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6.0                                 595   571   1166
# 1      Alaska           43.0                                 562   544   1106
# 2     Arizona           29.0                                 577   572   1149
# 3    Arkansas            5.0                                 592   576   1169
# 4  California           60.0                                 540   536   1076

# %% [markdown]
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.

# %%
sat_18.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat_19.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
# Renaming columns for SATs
sat_18.columns = [col.replace(' ', '_').lower() for col in sat_18.columns]
sat_19.columns = [col.replace(' ', '_').lower() for col in sat_19.columns]

# %%
# check
print(sat_18.columns)
# Out:
# Index(['state', 'participation', 'evidence-based_reading_and_writing', 'math',
#        'total'],
#       dtype='object')

# %%
# check
print(sat_19.columns)
# Out:
# Index(['state', 'participation_rate', 'ebrw', 'math', 'total'], dtype='object')

# %%
# check sample
sat_18.head()
# Out:
#         state  participation  evidence-based_reading_and_writing  math  total
# 0     Alabama            6.0                                 595   571   1166
# 1      Alaska           43.0                                 562   544   1106
# 2     Arizona           29.0                                 577   572   1149
# 3    Arkansas            5.0                                 592   576   1169
# 4  California           60.0                                 540   536   1076

# %%
# 8. Drop unnecessary rows (if needed).
sat_18.shape
# Out:
# (51, 5)

# %%
sat_19.shape
# Out:
# (53, 5)

# %%
sat_19.tail()
# Out:
#             state  participation_rate  ebrw  math  total
# 48       Virginia                68.0   567   551   1119
# 49     Washington                70.0   539   535   1074
# 50  West Virginia                99.0   483   460    943
# 51      Wisconsin                 3.0   635   648   1283
# 52        Wyoming                 3.0   623   615   1238

# %%
sat_18.tail()
# Out:
#             state  participation  evidence-based_reading_and_writing  math  \
# 46       Virginia           68.0                                 567   550
# 47     Washington           69.0                                 543   538
# 48  West Virginia           28.0                                 513   486
# 49      Wisconsin            3.0                                 641   653
# 50        Wyoming            3.0                                 633   625
#
#     total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %% [markdown]
# * sat_18 and sat_19 have different sizes

# %%
# 9. Merge dataframes that can be merged.
# rename columns
sat_18.rename(columns={
    'participation': '2018_sat_participation_rate',
    'evidence-based_reading_and_writing': '2018_sat_ebrw',
    'math': '2018_sat_math',
    'total': '2018_sat_total'
}, inplace=True)

sat_19.rename(columns={
    'participation_rate': '2019_sat_participation_rate',
    'ebrw': '2019_sat_ebrw',
    'math': '2019_sat_math',
    'total': '2019_sat_total'
}, inplace=True)

# %%
sat_18.head()
# Out:
#         state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 0     Alabama                          6.0            595            571
# 1      Alaska                         43.0            562            544
# 2     Arizona                         29.0            577            572
# 3    Arkansas                          5.0            592            576
# 4  California                         60.0            540            536
#
#    2018_sat_total
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
sat_19.head()
# Out:
#         state  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 0     Alabama                          7.0            583            560
# 1      Alaska                         41.0            556            541
# 2     Arizona                         31.0            569            565
# 3    Arkansas                          6.0            582            559
# 4  California                         63.0            534            531
#
#    2019_sat_total
# 0            1143
# 1            1097
# 2            1134
# 3            1141
# 4            1065

# %%
print('SAT_18 size: ', sat_18.shape)
print('SAT_19 size: ', sat_19.shape)
# Out:
# SAT_18 size:  (51, 5)
# SAT_19 size:  (53, 5)

# %%
#sat18_19 = pd.merge(sat_19, sat_18,  how = 'left')

# %%
sat18_19 = pd.merge(sat_18, sat_19, on = 'state')

# %%
sat18_19.head()
# Out:
#         state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 0     Alabama                          6.0            595            571
# 1      Alaska                         43.0            562            544
# 2     Arizona                         29.0            577            572
# 3    Arkansas                          5.0            592            576
# 4  California                         60.0            540            536
#
#    2018_sat_total  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 0            1166                          7.0            583            560
# 1            1106                         41.0            556            541
# 2            1149                         31.0            569            565
# 3            1169                          6.0            582            559
# 4            1076                         63.0            534            531
#
#    2019_sat_total
# 0            1143
# 1            1097
# ...

# %%
sat18_19.shape
# Out:
# (51, 9)

# %%
sat18_19.tail()
# Out:
#             state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 46       Virginia                         68.0            567            550
# 47     Washington                         69.0            543            538
# 48  West Virginia                         28.0            513            486
# 49      Wisconsin                          3.0            641            653
# 50        Wyoming                          3.0            633            625
#
#     2018_sat_total  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 46            1117                         68.0            567            551
# 47            1081                         70.0            539            535
# 48             999                         99.0            483            460
# 49            1294                          3.0            635            648
# 50            1257                          3.0            623            615
#
#     2019_sat_total
# ...

# %%
# Renaming columns for ACTs
act_18.columns = [col.replace(' ', '_').lower() for col in act_18.columns]
act_19.columns = [col.replace(' ', '_').lower() for col in act_19.columns]

# %%
act_18.columns
# Out:
# Index(['state', 'participation', 'composite'], dtype='object')

# %%
act_19.columns
# Out:
# Index(['state', 'participation', 'composite'], dtype='object')

# %%
# rename columns
act_18.rename(columns={
    'participation': '2018_act_participation_rate',
    'composite': '2018_act_composite'
}, inplace=True)

act_19.rename(columns={
    'participation': '2019_act_participation_rate',
    'composite': '2019_act_composite'
}, inplace=True)

# %%
act18_19 = pd.merge(act_18, act_19, on = 'state')

# %%
act18_19.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6

# %%
act18_19.shape
# Out:
# (51, 5)

# %%
act_18_19 = pd.merge(act_18, act_19, on = 'state', how = 'outer')
act_18_19.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6

# %%
act_18_19.shape
# Out:
# (54, 5)

# %%
act_18_19.tail()
# Out:
#                    state  2018_act_participation_rate  2018_act_composite  \
# 49         West Virginia                         65.0                20.3
# 50             Wisconsin                        100.0                20.5
# 51               Wyoming                        100.0                20.0
# 52  District of Columbia                          NaN                 NaN
# 53              National                          NaN                 NaN
#
#     2019_act_participation_rate  2019_act_composite
# 49                         49.0                20.8
# 50                        100.0                20.3
# 51                        100.0                19.8
# 52                         32.0                23.5
# 53                         52.0                20.7

# %%
sat_18_19 = pd.merge(sat_18, sat_19, on = 'state', how = 'outer')
sat_18_19.head()
# Out:
#         state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 0     Alabama                          6.0          595.0          571.0
# 1      Alaska                         43.0          562.0          544.0
# 2     Arizona                         29.0          577.0          572.0
# 3    Arkansas                          5.0          592.0          576.0
# 4  California                         60.0          540.0          536.0
#
#    2018_sat_total  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 0          1166.0                          7.0            583            560
# 1          1106.0                         41.0            556            541
# 2          1149.0                         31.0            569            565
# 3          1169.0                          6.0            582            559
# 4          1076.0                         63.0            534            531
#
#    2019_sat_total
# 0            1143
# 1            1097
# ...

# %%
sat_18_19.shape
# Out:
# (53, 9)

# %%
sat_18_19.tail()
# Out:
#              state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 48   West Virginia                         28.0          513.0          486.0
# 49       Wisconsin                          3.0          641.0          653.0
# 50         Wyoming                          3.0          633.0          625.0
# 51     Puerto Rico                          NaN            NaN            NaN
# 52  Virgin Islands                          NaN            NaN            NaN
#
#     2018_sat_total  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 48           999.0                         99.0            483            460
# 49          1294.0                          3.0            635            648
# 50          1257.0                          3.0            623            615
# 51             NaN                          1.0            483            462
# 52             NaN                          1.0            490            445
#
#     2019_sat_total
# ...

# %%
# 10. Perform any additional cleaning that you feel is necessary.

# %%
# 11. Save your cleaned and merged dataframes as csv files.
act18_19.to_csv('cleaned_data/act_df.csv',index=False) 
sat18_19.to_csv('cleaned_data/sat_df.csv',index=False)
# I'm using the `OUTER JOIN`
act_18_19.to_csv('cleaned_data/actdf.csv',index=False) 
sat_18_19.to_csv('cleaned_data/satdf.csv',index=False)

# %%
# read and display sample rows for the merged ACT 
ACT_df = pd.read_csv('cleaned_data/actdf.csv')
ACT_df.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6

# %%
# # set 'state' as index
# ACT_df.set_index('state', inplace=True)
# # check the change
# ACT_df.head()

# %%
# read and display sample rows for the merged SAT 
SATdf = pd.read_csv('cleaned_data/satdf.csv')
SATdf.head()
# Out:
#         state  2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  \
# 0     Alabama                          6.0          595.0          571.0
# 1      Alaska                         43.0          562.0          544.0
# 2     Arizona                         29.0          577.0          572.0
# 3    Arkansas                          5.0          592.0          576.0
# 4  California                         60.0          540.0          536.0
#
#    2018_sat_total  2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  \
# 0          1166.0                          7.0            583            560
# 1          1106.0                         41.0            556            541
# 2          1149.0                         31.0            569            565
# 3          1169.0                          6.0            582            559
# 4          1076.0                         63.0            534            531
#
#    2019_sat_total
# 0            1143
# 1            1097
# ...

# %%
# # set 'state' as index
# SATdf.set_index('state', inplace=True)
# # check the change
# SATdf.head()

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions.
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**| *object*|SAT-HigherEd|States in the US and District of Columbia|
# |**2018_participation_rate**|*float64*|SAT-HigherEd|percentage rate among high school seniors in 2018|
# |**2018_ebrw**|*int64*|SAT-HigherEd	|The average score of the ***Evidence-Based Reading and Writing*** section in 2018 (out of 800)|
# |**2018_math**|*int64*|SAT-HigherEd|The average score of the Mathematics section in 2018 (out of 800)|
# |**2018_math**|*int64*|SAT-HigherEd	|The average score of the Mathematics section in 2018 (out of 800)|
# |**2018_total**|*int64*|SAT-HigherEd|The average of the total SAT score in 2018 (out of 1600)|
# |**2019_participation_rate**|*float64*|SAT-HigherEd|percentage rate among high school seniors in 2019|
# |**2019_ebrw**|*int64*|SAT-HigherEd	|The average score of the ***Evidence-Based Reading and Writing*** section in 2018 (out of 800)|
# |**2019_math**|*int64*|SAT-HigherEd|The average score of the Mathematics section in 2019 (out of 800)|
# |**2019_math**|*int64*|SAT-HigherEd	|The average score of the Mathematics section in 2019 (out of 800)|
# |**2019_total**|*int64*|SAT-HigherEd|The average of the total SAT score in 2019 (out of 1600)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# 1. Summary Statistics.

# %%
# merge both SAT and ACT dataframe to make one df
df = pd.merge(ACT_df, SATdf, on = 'state', how = 'outer')
df.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite  \
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6
#
#    2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                          6.0          595.0          571.0          1166.0
# 1                         43.0          562.0          544.0          1106.0
# ...

# %%
#Code: statistical summary
df.describe().T
# Out:
#                              count         mean         std    min       25%  \
# 2018_act_participation_rate   52.0    60.673077   34.545634    7.0    27.000
# 2018_act_composite            52.0    21.544231    2.119417   17.7    19.975
# 2019_act_participation_rate   53.0    57.547170   34.618562    6.0    24.000
# 2019_act_composite            53.0    21.503774    2.189746   17.9    19.800
# 2018_sat_participation_rate   52.0    46.769231   37.677483    2.0     4.750
# 2018_sat_ebrw                 52.0   562.692308   47.577610  480.0   530.500
# 2018_sat_math                 52.0   555.173077   47.918117  480.0   521.750
# 2018_sat_total                52.0  1117.961538   94.401305  977.0  1047.750
# 2019_sat_participation_rate   54.0    48.203704   39.368304    1.0     4.250
# 2019_sat_ebrw                 54.0   557.148148   47.517785  483.0   516.500
# 2019_sat_math                 54.0   547.611111   53.649251  445.0   504.500
# ...

# %% [markdown]
# * we can easily see the **range** = max - min
# * We can also infer that SAT mean participation increased from 45.5% in 2018 to to 49.1% in 2019 although the mean score shows a decrease.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 0 to 55
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        56 non-null     object
#  1   2018_act_participation_rate  52 non-null     float64
#  2   2018_act_composite           52 non-null     float64
#  3   2019_act_participation_rate  53 non-null     float64
#  4   2019_act_composite           53 non-null     float64
#  5   2018_sat_participation_rate  52 non-null     float64
#  6   2018_sat_ebrw                52 non-null     float64
#  7   2018_sat_math                52 non-null     float64
#  8   2018_sat_total               52 non-null     float64
#  9   2019_sat_participation_rate  54 non-null     float64
#  10  2019_sat_ebrw                54 non-null     float64
#  11  2019_sat_math                54 non-null     float64
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# average values for each
df.mean()
# Out:
# 2018_act_participation_rate      60.673077
# 2018_act_composite               21.544231
# 2019_act_participation_rate      57.547170
# 2019_act_composite               21.503774
# 2018_sat_participation_rate      46.769231
# 2018_sat_ebrw                   562.692308
# 2018_sat_math                   555.173077
# 2018_sat_total                 1117.961538
# 2019_sat_participation_rate      48.203704
# 2019_sat_ebrw                   557.148148
# 2019_sat_math                   547.611111
# 2019_sat_total                 1104.796296
# dtype: float64

# %%
df['2019_act_participation_rate'].min()
# Out:
# 6.0

# %%
df['2019_act_participation_rate'].std() # standard deviation
# Out:
# 34.61856218281206

# %% [markdown]
# * Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# again we're defining a function to calculate standard deviation using the formula above
def std_dev(s):
    try:
        n = len(s)
        mean = s.mean()
        sum = 0
        for i in range(n):
            sum += (s[i] - mean)**2
        return (sum/n)**0.5
    except:
        pass

# %%
print('2018 ACT Participation rate is: ',std_dev(df['2018_act_participation_rate']))
print('2019 ACT Participation rate is: ',std_dev(df['2019_act_participation_rate']))
# Out:
# 2018 ACT Participation rate is:  nan
# 2019 ACT Participation rate is:  nan

# %%
std_dev(df['2019_sat_ebrw'])
# Out:
# nan

# %% [markdown]
# * Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
std_dev_dict = {k: std_dev(v) for k, v in df.iteritems()}
std_dev_dict
# Out:
# {'state': None,
#  '2018_act_participation_rate': nan,
#  '2018_act_composite': nan,
#  '2019_act_participation_rate': nan,
#  '2019_act_composite': nan,
#  '2018_sat_participation_rate': nan,
#  '2018_sat_ebrw': nan,
#  '2018_sat_math': nan,
#  '2018_sat_total': nan,
#  '2019_sat_participation_rate': nan,
#  '2019_sat_ebrw': nan,
#  '2019_sat_math': nan,
#  '2019_sat_total': nan}

# %% [markdown]
# * Do your manually calculated standard deviations match up with the output from pandas describe? What about numpy's std method?

# %%
std_dev(df['2018_act_participation_rate'])
# Out:
# nan

# %%
import numpy as np
np.std(df['2018_act_participation_rate'])
# Out:
# 34.21185194650338

# %% [markdown]
# **Answer:** <br>
# They match numpy's std method but not pandas describe.

# %% [markdown]
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Investigate trends in the data
# *  Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?

# %% [markdown]
# * 3a) **Let's try to answer, which states have the highest and lowest participation rates for the:** <br>
#    * 2018 ACT?
#    * 2019 ACT?
#    * 2018 SAT?
#    * 2019 SAT?

# %%
df.columns
# Out:
# Index(['state', '2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
#  2018 ACT participation
df.sort_values(by=['2018_act_participation_rate'], ascending=False).head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 17   Kentucky                        100.0                20.2
# 50  Wisconsin                        100.0                20.5
# 45       Utah                        100.0                20.4
# 43  Tennessee                        100.0                19.6
#
#     2019_act_participation_rate  2019_act_composite  \
# 0                         100.0                18.9
# 17                        100.0                19.8
# 50                        100.0                20.3
# 45                        100.0                20.3
# 43                        100.0                19.4
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                           6.0          595.0          571.0          1166.0
# 17                          4.0          630.0          618.0          1248.0
# ...

# %%
#  2019 ACT participation
df.sort_values(by=['2019_act_participation_rate'], ascending=False).head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 17   Kentucky                        100.0                20.2
# 51    Wyoming                        100.0                20.0
# 50  Wisconsin                        100.0                20.5
# 45       Utah                        100.0                20.4
#
#     2019_act_participation_rate  2019_act_composite  \
# 0                         100.0                18.9
# 17                        100.0                19.8
# 51                        100.0                19.8
# 50                        100.0                20.3
# 45                        100.0                20.3
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                           6.0          595.0          571.0          1166.0
# 17                          4.0          630.0          618.0          1248.0
# ...

# %%
#  2018 SAT participation
df.sort_values(by=['2018_sat_participation_rate'], ascending=False).head()
# Out:
#           state  2018_act_participation_rate  2018_act_composite  \
# 23     Michigan                         22.0                24.2
# 5      Colorado                         30.0                23.9
# 6   Connecticut                         26.0                25.6
# 7      Delaware                         17.0                23.8
# 12        Idaho                         36.0                22.3
#
#     2019_act_participation_rate  2019_act_composite  \
# 23                         19.0                24.4
# 5                          27.0                23.8
# 6                          22.0                25.5
# 7                          13.0                24.1
# 12                         31.0                22.5
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 23                        100.0          511.0          499.0          1011.0
# 5                         100.0          519.0          506.0          1025.0
# ...

# %%
#  2019 SAT participation
df.sort_values(by=['2019_sat_participation_rate'], ascending=False).head()
# Out:
#           state  2018_act_participation_rate  2018_act_composite  \
# 12        Idaho                         36.0                22.3
# 23     Michigan                         22.0                24.2
# 5      Colorado                         30.0                23.9
# 6   Connecticut                         26.0                25.6
# 7      Delaware                         17.0                23.8
#
#     2019_act_participation_rate  2019_act_composite  \
# 12                         31.0                22.5
# 23                         19.0                24.4
# 5                          27.0                23.8
# 6                          22.0                25.5
# 7                          13.0                24.1
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 12                        100.0          508.0          493.0          1001.0
# 23                        100.0          511.0          499.0          1011.0
# ...

# %%
df[df['2018_sat_participation_rate'] == df['2018_sat_participation_rate'].max()]['state'].head()
# Out:
# 5        Colorado
# 6     Connecticut
# 7        Delaware
# 12          Idaho
# 23       Michigan
# Name: state, dtype: object

# %%
df.sort_values(by=['2018_sat_participation_rate'], ascending=False).head()
# Out:
#           state  2018_act_participation_rate  2018_act_composite  \
# 23     Michigan                         22.0                24.2
# 5      Colorado                         30.0                23.9
# 6   Connecticut                         26.0                25.6
# 7      Delaware                         17.0                23.8
# 12        Idaho                         36.0                22.3
#
#     2019_act_participation_rate  2019_act_composite  \
# 23                         19.0                24.4
# 5                          27.0                23.8
# 6                          22.0                25.5
# 7                          13.0                24.1
# 12                         31.0                22.5
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 23                        100.0          511.0          499.0          1011.0
# 5                         100.0          519.0          506.0          1025.0
# ...

# %% [markdown]
# * 3b) **Which states have the highest and lowest mean total/composite scores for the:** <br>
#    * 2018 ACT?
#    * 2019 ACT?
#    * 2018 SAT?
#    * 2019 SAT?

# %%
df.columns
# Out:
# Index(['state', '2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
df.groupby(by='state')[['2018_act_participation_rate', 
                         '2019_act_participation_rate',
                        '2018_sat_participation_rate', 
                         '2019_sat_participation_rate',
                         '2018_act_composite','2019_act_composite', 
                         '2018_sat_total','2019_sat_total']].agg(
                            ['mean']).sort_values(by='state', ascending=False).head()
# Out:
#               2018_act_participation_rate 2019_act_participation_rate  \
#                                      mean                        mean
# state
# Wyoming                             100.0                       100.0
# Wisconsin                           100.0                       100.0
# West Virginia                        65.0                        49.0
# Washington                           24.0                        24.0
# Virginia                             24.0                        21.0
#
#               2018_sat_participation_rate 2019_sat_participation_rate  \
#                                      mean                        mean
# state
# Wyoming                               3.0                         3.0
# Wisconsin                             3.0                         3.0
# West Virginia                        28.0                        99.0
# Washington                           69.0                        70.0
# ...

# %%
df.groupby(by='state')[['2018_act_composite',
                        '2019_act_composite', 
                        '2018_sat_total',
                        '2019_sat_total']].agg(['mean']).sort_values(by='state', ascending=False).head()
# Out:
#               2018_act_composite 2019_act_composite 2018_sat_total  \
#                             mean               mean           mean
# state
# Wyoming                     20.0               19.8         1257.0
# Wisconsin                   20.5               20.3         1294.0
# West Virginia               20.3               20.8          999.0
# Washington                  22.2               22.1         1081.0
# Virginia                    23.9               24.0         1117.0
#
#               2019_sat_total
#                         mean
# state
# Wyoming               1238.0
# Wisconsin             1283.0
# West Virginia          943.0
# Washington            1074.0
# Virginia              1119.0

# %% [markdown]
# * 3c) **Do any states with 100% participation on a given test have a rate change year-to-year?** <br>

# %%
df[(df['2018_act_participation_rate'] == 100) & (df['2019_act_participation_rate'] < 100)]
# Out:
#              state  2018_act_participation_rate  2018_act_composite  \
# 26        Missouri                        100.0                20.0
# 41  South Carolina                        100.0                18.3
#
#     2019_act_participation_rate  2019_act_composite  \
# 26                         82.0                20.8
# 41                         78.0                18.8
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 26                          4.0          633.0          629.0          1262.0
# 41                         55.0          547.0          523.0          1070.0
#
#     2019_sat_participation_rate  2019_sat_ebrw  2019_sat_math  2019_sat_total
# 26                          4.0          622.0          615.0          1236.0
# 41                         68.0          526.0          504.0          1030.0

# %%
df[(df['2018_sat_participation_rate'] == 100) & (df['2019_sat_participation_rate'] < 100)]
# Out:
# Empty DataFrame
# Columns: [state, 2018_act_participation_rate, 2018_act_composite, 2019_act_participation_rate, 2019_act_composite, 2018_sat_participation_rate, 2018_sat_ebrw, 2018_sat_math, 2018_sat_total, 2019_sat_participation_rate, 2019_sat_ebrw, 2019_sat_math, 2019_sat_total]
# Index: []

# %% [markdown]
# * 3d) **Do any states show have >50% participation on *both* tests each year?**

# %%
#df[(df['2018_sat_participation_rate'] > 50) & (df['2019_sat_participation_rate'] > 50)]

# %%
#df[(df['2018_act_participation_rate'] > 50) & (df['2019_act_participation_rate'] > 50)]

# %%
df.describe().T
# Out:
#                              count         mean         std    min       25%  \
# 2018_act_participation_rate   52.0    60.673077   34.545634    7.0    27.000
# 2018_act_composite            52.0    21.544231    2.119417   17.7    19.975
# 2019_act_participation_rate   53.0    57.547170   34.618562    6.0    24.000
# 2019_act_composite            53.0    21.503774    2.189746   17.9    19.800
# 2018_sat_participation_rate   52.0    46.769231   37.677483    2.0     4.750
# 2018_sat_ebrw                 52.0   562.692308   47.577610  480.0   530.500
# 2018_sat_math                 52.0   555.173077   47.918117  480.0   521.750
# 2018_sat_total                52.0  1117.961538   94.401305  977.0  1047.750
# 2019_sat_participation_rate   54.0    48.203704   39.368304    1.0     4.250
# 2019_sat_ebrw                 54.0   557.148148   47.517785  483.0   516.500
# 2019_sat_math                 54.0   547.611111   53.649251  445.0   504.500
# ...

# %% [markdown]
# * 3e) **Which colleges have the highest median SAT and ACT scores for admittance?**

# %%
df['2018_act_composite'].median()
# Out:
# 21.3

# %%
df.groupby(by='state')[['2018_act_composite',
                        '2019_act_composite', 
                        '2018_sat_total',
                        '2019_sat_total']].median().head()
# Out:
#             2018_act_composite  2019_act_composite  2018_sat_total  \
# state
# Alabama                   19.1                18.9          1166.0
# Alaska                    20.8                20.1          1106.0
# Arizona                   19.2                19.0          1149.0
# Arkansas                  19.4                19.3          1169.0
# California                22.7                22.6          1076.0
#
#             2019_sat_total
# state
# Alabama             1143.0
# Alaska              1097.0
# Arizona             1134.0
# Arkansas            1141.0
# California          1065.0

# %% [markdown]
# * 3f) **Which California school districts have the highest and lowest mean test scores?**

# %%
df.groupby(by='state')[['2018_act_composite',
                        '2019_act_composite', 
                        '2018_sat_total',
                        '2019_sat_total']].median().head()
# Out:
#             2018_act_composite  2019_act_composite  2018_sat_total  \
# state
# Alabama                   19.1                18.9          1166.0
# Alaska                    20.8                20.1          1106.0
# Arizona                   19.2                19.0          1149.0
# Arkansas                  19.4                19.3          1169.0
# California                22.7                22.6          1076.0
#
#             2019_sat_total
# state
# Alabama             1143.0
# Alaska              1097.0
# Arizona             1134.0
# Arkansas            1141.0
# California          1065.0

# %%
df.sort_values(by=['2018_sat_total'], ascending=False).mean().head()
# Out:
# 2018_act_participation_rate    60.673077
# 2018_act_composite             21.544231
# 2019_act_participation_rate    57.547170
# 2019_act_composite             21.503774
# 2018_sat_participation_rate    46.769231
# dtype: float64

# %%
# Top 10 act participant states in 2018

state_df = df.sort_values(by='2018_act_participation_rate', ascending=False) 
top_ten_state_df = state_df.iloc[:10, :]
top_ten_state_df
# Out:
#              state  2018_act_participation_rate  2018_act_composite  \
# 0          Alabama                        100.0                19.1
# 17        Kentucky                        100.0                20.2
# 50       Wisconsin                        100.0                20.5
# 45            Utah                        100.0                20.4
# 43       Tennessee                        100.0                19.6
# 41  South Carolina                        100.0                18.3
# 37        Oklahoma                        100.0                19.3
# 36            Ohio                        100.0                20.3
# 34  North Carolina                        100.0                19.1
# 29          Nevada                        100.0                17.7
#
#     2019_act_participation_rate  2019_act_composite  \
# 0                         100.0                18.9
# 17                        100.0                19.8
# 50                        100.0                20.3
# ...

# %%
# Top 10 act participating states in 2019

state_df = df.sort_values(by='2019_act_participation_rate', ascending=False) 
top_ten19_state_df = state_df.iloc[:10, :]
top_ten19_state_df
# Out:
#              state  2018_act_participation_rate  2018_act_composite  \
# 0          Alabama                        100.0                19.1
# 17        Kentucky                        100.0                20.2
# 51         Wyoming                        100.0                20.0
# 50       Wisconsin                        100.0                20.5
# 45            Utah                        100.0                20.4
# 43       Tennessee                        100.0                19.6
# 37        Oklahoma                        100.0                19.3
# 36            Ohio                        100.0                20.3
# 34  North Carolina                        100.0                19.1
# 29          Nevada                        100.0                17.7
#
#     2019_act_participation_rate  2019_act_composite  \
# 0                         100.0                18.9
# 17                        100.0                19.8
# 51                        100.0                19.8
# ...

# %%
df.sort_values(by=['2018_act_composite'], ascending=False).head()
# Out:
#             state  2018_act_participation_rate  2018_act_composite  \
# 6     Connecticut                         26.0                25.6
# 22  Massachusetts                         25.0                25.5
# 30  New Hampshire                         16.0                25.1
# 33       New York                         27.0                24.5
# 23       Michigan                         22.0                24.2
#
#     2019_act_participation_rate  2019_act_composite  \
# 6                          22.0                25.5
# 22                         21.0                25.5
# 30                         14.0                25.0
# 33                         22.0                24.5
# 23                         19.0                24.4
#
#     2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 6                         100.0          535.0          519.0          1053.0
# 22                         80.0          562.0          563.0          1125.0
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
#
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
#
# ![](./2019_SAT_Score.png)
#
# Heatmap ffor the 2018 and 2019 SAT Scores; where:
#
# * ebwr means the "Evidence Based Reading and Writing" test; sometimes we refer it as verbal test, and
# * 2018_math means, for example, SAT Mathematics test for the year 2018.
#
#
# ![](./2018-2019-SAT-Score-Heatmap.png)
#
#
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
df.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite  \
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6
#
#    2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                          6.0          595.0          571.0          1166.0
# 1                         43.0          562.0          544.0          1106.0
# ...

# %%
sns.heatmap(df.corr());

# %%
plt.figure(figsize=(16, 8))
plt.title('SAT ACT 2018 2019 heatmap')

ax = sns.heatmap(df.corr(), linewidths=.5, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

ax;

# %% [markdown]
# more on [Matplotlib](https://matplotlib.org/2.0.2/users/pyplot_tutorial.html) graphs.

# %%
# helper function

def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, ylimit=None, medianline=False):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    if ylimit:
        fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(16, 5*nrows), sharey=True) # You'll want to specify your figsize
        plt.yticks(np.arange(0, ylimit+1, np.floor((ylimit)/10)))
    else:
        fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(16, 10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], edgecolor='black', linewidth=2) # feel free to add more settings
        if medianline:
            ax[i].axvline(np.median(dataframe[column]), color='red', linestyle='dashed', linewidth=1)
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# ### Plot and interpret histograms
# **For each of the following:**
#
#    * Participation rates for SAT & ACT
#    * Math scores for SAT & ACT
#    * Reading/verbal scores for SAT & ACT <br>
#
# ### Participation rates for SAT & ACT

# %%
df.columns
# Out:
# Index(['state', '2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
cols = ['2018_sat_participation_rate', '2018_act_participation_rate',  '2019_sat_participation_rate', '2019_act_participation_rate']
titles = ['SAT 2018 participation rate', 'ACT 2018 participation rate', 'SAT 2019 participation rate', 'ACT 2019 participation rate']
xlabels = ['percentage' for i in range(len(titles))]
subplot_histograms(df, cols, titles, xlabels, ylimit=22, medianline=True)

# %%
# Math scores for SAT & composite for ACT
cols = ['2018_sat_math', '2018_act_composite', '2019_sat_math', '2019_act_composite']
titles = ['SAT 2018 math score (out of 800)', 'ACT 2018 composite score (out of 36)', 'SAT 2019 math score (out of 800)', 'ACT 2018 composite score (out of 36)']
xlabels = ['score' for i in range(len(titles))]
subplot_histograms(df, cols, titles, xlabels, ylimit=14, medianline=True)

# %%
# To see an overview of the correlation of each variable in the dataset:
sns.pairplot(df, height=3, aspect=1);

# %%
df.columns
# Out:
# Index(['2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
# Distribution pattern for 2018 SAT score
fig, ax = plt.subplots(3,1,figsize=(14,12))
sns.histplot(df['2018_act_participation_rate'], bins=30, kde=False, ax=ax[0])
sns.histplot(df['2018_sat_ebrw'], bins=30, kde=False, color='g', ax=ax[1])
sns.histplot(df['2018_sat_math'], bins=30, kde=False,color='r', ax=ax[2]);

# %%
# Distribution pattern for 2019 SAT score
fig, ax = plt.subplots(3,1,figsize=(14,12))
sns.histplot(df['2019_act_participation_rate'], bins=30, kde=False, ax=ax[0])
sns.histplot(df['2019_sat_ebrw'], bins=30, kde=False, color='g', ax=ax[1])
sns.histplot(df['2019_sat_math'], bins=30, kde=False,color='r', ax=ax[2]);

# %%
#Let's see 'math' Vs 'ebrw' for 2018

df[['2018_sat_math', '2018_sat_ebrw']].plot.hist(bins=30, alpha=0.5, stacked=True, figsize=(14,5))
plt.title("2018 SAT Performance")
plt.xlabel('Scores')
plt.ylabel('Number of States');

# %%
#Let's see 'math' Vs 'ebrw' for 2019

df[['2019_sat_math', '2019_sat_ebrw']].plot.hist(bins=30, alpha=0.5, stacked=True, figsize=(14,5))
plt.title("2019 SAT Performance")
plt.xlabel('Scores')
plt.ylabel('Number of States');

# %%
df.columns
# Out:
# Index(['2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
# 2018 SAT Boxplot Vs histogram for better visualization of how the data are spread out

fig, ax = plt.subplots(2,3, figsize=(25,6))

sns.boxplot(data=df['2018_sat_participation_rate'],orient='h', ax=ax[0][0])
sns.histplot(df['2018_sat_participation_rate'], ax=ax[1][0],kde=True,bins=30)

sns.boxplot(data=df['2018_sat_ebrw'], orient='h', ax=ax[0][1], color='orange')
sns.histplot(df['2018_sat_ebrw'], bins=30, ax=ax[1][1], kde=True, color='orange')

sns.boxplot(data=df['2018_sat_math'], orient='h', ax=ax[0][2], color='purple')
sns.histplot(df['2018_sat_math'], bins=30, ax=ax[1][2], kde=True, color='purple');

# %%
# 2019 SAT Boxplot Vs histogram for better visualization of how the data are spread out

fig, ax = plt.subplots(2,3, figsize=(25,6))

sns.boxplot(data=df['2019_sat_participation_rate'],orient='h', ax=ax[0][0])
sns.histplot(df['2019_sat_participation_rate'], ax=ax[1][0],kde=True,bins=30)

sns.boxplot(data=df['2019_sat_ebrw'], orient='h', ax=ax[0][1], color='orange')
sns.histplot(df['2019_sat_ebrw'], bins=30, ax=ax[1][1], kde=True, color='orange')

sns.boxplot(data=df['2019_sat_math'], orient='h', ax=ax[0][2], color='purple')
sns.histplot(df['2019_sat_math'], bins=30, ax=ax[1][2], kde=True, color='purple');

# %%
# To better see the boxplots, we normalize the variables: SAT

df_std = (df[['2018_sat_participation_rate','2019_sat_participation_rate','2018_sat_ebrw','2019_sat_ebrw','2018_sat_math', '2019_sat_math' ]] - df.mean()) / df.std()

fig = plt.figure(figsize=(14,9))
ax = fig.gca()

ax = sns.boxplot(data=df_std, orient='h', palette='Set2')
ax = plt.title('Standardized Boxplot for SAT Performance for the Year 2018 and 2019')

# %% [markdown]
# * Since 'participation_rates' doesn't have the same scale as 'ebrw' and 'math', we better standardize to the same scale using the formula:
# $$
# \frac{X-\mu}{\sigma }
# $$
# * From the boxplot, we see that there is no outlier point eventhogh SAT score distribution is so dispersed

# %%
df.describe().T
# Out:
#                              count         mean         std    min       25%  \
# 2018_act_participation_rate   52.0    60.673077   34.545634    7.0    27.000
# 2018_act_composite            52.0    21.544231    2.119417   17.7    19.975
# 2019_act_participation_rate   53.0    57.547170   34.618562    6.0    24.000
# 2019_act_composite            53.0    21.503774    2.189746   17.9    19.800
# 2018_sat_participation_rate   52.0    46.769231   37.677483    2.0     4.750
# 2018_sat_ebrw                 52.0   562.692308   47.577610  480.0   530.500
# 2018_sat_math                 52.0   555.173077   47.918117  480.0   521.750
# 2018_sat_total                52.0  1117.961538   94.401305  977.0  1047.750
# 2019_sat_participation_rate   54.0    48.203704   39.368304    1.0     4.250
# 2019_sat_ebrw                 54.0   557.148148   47.517785  483.0   516.500
# 2019_sat_math                 54.0   547.611111   53.649251  445.0   504.500
# ...

# %% [markdown]
# - Verbal mean: 563.69 for 2018 and 560.80 for 2019
# - Math mean: 556.24 for 2018 and 552.20 for 2019 statewide.
#
# Now to see which states have greater than these mean values.

# %%
df['2018_sat_ebrw'].mean()
# Out:
# 562.6923076923077

# %%
df['2018_sat_participation_rate'].mean()
# Out:
# 46.76923076923077

# %%
df.columns
# Out:
# Index(['state', '2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total'],
#       dtype='object')

# %%
plt.subplots(figsize=(16, 10))
plt.ylim(12, 30)
plt.title('ACT scores')
xticklabels = ['2018 ACT composite', '2019 ACT composite', '2018 SAT reading',  '2018 SAT math', '2019 SAT reading', '2019 SAT  math']
sns.boxplot(data=df[['2018_act_composite', '2019_act_composite',  '2018_sat_ebrw', '2018_sat_math', '2019_sat_ebrw', '2019_sat_math']]).set_xticklabels(xticklabels, rotation=45, ha='right')
# Out:
# [Text(0, 0, '2018 ACT composite'),
#  Text(1, 0, '2019 ACT composite'),
#  Text(2, 0, '2018 SAT reading'),
#  Text(3, 0, '2018 SAT math'),
#  Text(4, 0, '2019 SAT reading'),
#  Text(5, 0, '2019 SAT  math')]

# %%
df['sat18_to_sat19_part_change'] = df['2019_sat_participation_rate'] - df['2018_sat_participation_rate']
df['sat18_to_sat19_part_change'].head()
# Out:
# 0    1.0
# 1   -2.0
# 2    2.0
# 3    1.0
# 4    3.0
# Name: sat18_to_sat19_part_change, dtype: float64

# %%
df[['state', '2018_sat_participation_rate', '2018_act_participation_rate',  'sat18_to_sat19_part_change', '2019_act_participation_rate']].sort_values('sat18_to_sat19_part_change', ascending=False).head(10)
# Out:
#                    state  2018_sat_participation_rate  \
# 49         West Virginia                         28.0
# 9                Florida                         56.0
# 37              Oklahoma                          8.0
# 41        South Carolina                         55.0
# 21              Maryland                         76.0
# 4             California                         60.0
# 40          Rhode Island                         97.0
# 38                Oregon                         48.0
# 14               Indiana                         63.0
# 52  District of Columbia                         92.0
#
#     2018_act_participation_rate  sat18_to_sat19_part_change  \
# 49                         65.0                        71.0
# 9                          66.0                        44.0
# 37                        100.0                        14.0
# 41                        100.0                        13.0
# 21                         31.0                         6.0
# ...

# %%
plt.figure(figsize=(16, 8))
plt.title('SAT ACT 2019 2018 heatmap')

ax = sns.heatmap(df.corr(), linewidths=.5, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

ax;

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(12, 8)) # You'll want to specify your figsize
ax.set_title('Change in SAT participation 2018-2019 vs ACT participation rate 2018')
ax.set_xlabel('Change in SAT participation rate 2018-2019')
ax.set_ylabel('ACT participation rate 2018')
ax.scatter(df['sat18_to_sat19_part_change'], df['2018_act_participation_rate'], s=100, alpha=0.7)
ax.plot([0,1],[0,1], transform=ax.transAxes, color='red', linestyle='dashed', linewidth=3)

fig = plt.gcf()
fig.savefig('./images/SAT-vs-ACT2018-2019.jpg')

# %%
df['s18_and_a19_total'] = df['2018_sat_participation_rate'] + df['2018_act_participation_rate']

# %%
df[['state', 's18_and_a19_total']].sort_values('s18_and_a19_total', ascending=True).head(10)
# Out:
#            state  s18_and_a19_total
# 15          Iowa               71.0
# 16        Kansas               75.0
# 1         Alaska               76.0
# 42  South Dakota               80.0
# 32    New Mexico               83.0
# 4     California               87.0
# 46       Vermont               88.0
# 38        Oregon               90.0
# 39  Pennsylvania               90.0
# 47      Virginia               92.0

# %% [markdown]
# => From these two tables, we see that North Dakota has the lowest participation but Colorado, Connecticut, Delaware, Michgan, and Idaho have 100% participation in 2018.

# %%
df.columns
# Out:
# Index(['state', '2018_act_participation_rate', '2018_act_composite',
#        '2019_act_participation_rate', '2019_act_composite',
#        '2018_sat_participation_rate', '2018_sat_ebrw', '2018_sat_math',
#        '2018_sat_total', '2019_sat_participation_rate', '2019_sat_ebrw',
#        '2019_sat_math', '2019_sat_total', 'sat18_to_sat19_part_change',
#        's18_and_a19_total'],
#       dtype='object')

# %%
mean_df = df.groupby(by='state')[['2018_sat_participation_rate', 
                                              '2019_sat_participation_rate', '2018_sat_ebrw','2019_sat_ebrw', 
                                              '2018_sat_math', '2019_sat_math']].agg(
                            ['mean', 'median']).sort_values(by='state', ascending=False)
mean_df.head()
# Out:
#               2018_sat_participation_rate        2019_sat_participation_rate  \
#                                      mean median                        mean
# state
# Wyoming                               3.0    3.0                         3.0
# Wisconsin                             3.0    3.0                         3.0
# West Virginia                        28.0   28.0                        99.0
# Washington                           69.0   69.0                        70.0
# Virginia                             68.0   68.0                        68.0
#
#                      2018_sat_ebrw        2019_sat_ebrw        2018_sat_math  \
#               median          mean median          mean median          mean
# state
# Wyoming          3.0         633.0  633.0         623.0  623.0         625.0
# Wisconsin        3.0         641.0  641.0         635.0  635.0         653.0
# West Virginia   99.0         513.0  513.0         483.0  483.0         486.0
# ...

# %%
mean_df.tail()
# Out:
#            2018_sat_participation_rate        2019_sat_participation_rate  \
#                                   mean median                        mean
# state
# California                        60.0   60.0                        63.0
# Arkansas                           5.0    5.0                         6.0
# Arizona                           29.0   29.0                        31.0
# Alaska                            43.0   43.0                        41.0
# Alabama                            6.0    6.0                         7.0
#
#                   2018_sat_ebrw        2019_sat_ebrw        2018_sat_math  \
#            median          mean median          mean median          mean
# state
# California   63.0         540.0  540.0         534.0  534.0         536.0
# Arkansas      6.0         592.0  592.0         582.0  582.0         576.0
# Arizona      31.0         577.0  577.0         569.0  569.0         572.0
# ...

# %%
df.skew()
# Out:
# 2018_act_participation_rate   -0.011274
# 2018_act_composite             0.225816
# 2019_act_participation_rate    0.069194
# 2019_act_composite             0.298442
# 2018_sat_participation_rate    0.102385
# 2018_sat_ebrw                  0.314288
# 2018_sat_math                  0.552821
# 2018_sat_total                 0.491681
# 2019_sat_participation_rate    0.053404
# 2019_sat_ebrw                  0.281267
# 2019_sat_math                  0.235672
# 2019_sat_total                 0.259206
# sat18_to_sat19_part_change     4.898697
# s18_and_a19_total              0.576751
# dtype: float64

# %%
# Calculating SAT participation changes from 2018 to 2019

df['sat_participation_change'] = df['2019_sat_participation_rate']- df['2018_sat_participation_rate']

# %%
df.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite  \
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6
#
#    2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                          6.0          595.0          571.0          1166.0
# 1                         43.0          562.0          544.0          1106.0
# ...

# %%
# Participation rate drop in 2019

df.sort_values('sat_participation_change', ascending=False)[['state', 
                                    '2018_sat_participation_rate', '2019_sat_participation_rate', 
                                                'sat_participation_change']].tail()
# Out:
#                    state  2018_sat_participation_rate  \
# 29                Nevada                         23.0
# 8   District of columbia                          NaN
# 53              National                          NaN
# 54           Puerto Rico                          NaN
# 55        Virgin Islands                          NaN
#
#     2019_sat_participation_rate  sat_participation_change
# 29                         20.0                      -3.0
# 8                           NaN                       NaN
# 53                          NaN                       NaN
# 54                          1.0                       NaN
# 55                          1.0                       NaN

# %% [markdown]
# * We see that Florida's participation rate increased by 71% from 2018 to 2019 whereas, Nevada's participation rate dropped by 3% in 2019.

# %%
# Top 10 satates who scored more than the national average in 2018 Math Test
sat18_above_mean_math = df[df['2018_sat_math'] > df['2018_sat_math'].mean()].sort_values(by='2018_sat_math', ascending=False).head(10)
sat18_above_mean_math
# Out:
#            state  2018_act_participation_rate  2018_act_composite  \
# 24     Minnesota                         99.0                21.3
# 50     Wisconsin                        100.0                20.5
# 35  North Dakota                         98.0                20.3
# 15          Iowa                         68.0                21.8
# 16        Kansas                         71.0                21.6
# 26      Missouri                        100.0                20.0
# 51       Wyoming                        100.0                20.0
# 28      Nebraska                        100.0                20.1
# 17      Kentucky                        100.0                20.2
# 42  South Dakota                         77.0                21.9
#
#     2019_act_participation_rate  2019_act_composite  \
# 24                         95.0                21.4
# 50                        100.0                20.3
# 35                         96.0                19.9
# ...

# %%
df.drop('sat_participation_change', axis=1, inplace=True)

# %%
df.head()
# Out:
#         state  2018_act_participation_rate  2018_act_composite  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    2019_act_participation_rate  2019_act_composite  \
# 0                        100.0                18.9
# 1                         38.0                20.1
# 2                         73.0                19.0
# 3                        100.0                19.3
# 4                         23.0                22.6
#
#    2018_sat_participation_rate  2018_sat_ebrw  2018_sat_math  2018_sat_total  \
# 0                          6.0          595.0          571.0          1166.0
# 1                         43.0          562.0          544.0          1106.0
# ...

# %%
# Correlation Heatmap
#Seaborn Heatmap visualizes correlation between all numeric features

fig = plt.figure(figsize=(16,12))
ax = sns.heatmap(df.corr(), annot=True, cmap="RdBu", center=0)
ax.set_title("Correlation Heatmap for 2018 and 2019 SAT Score")
plt.savefig('2018-2019-SAT-Score-Heatmap.png');

# %%
# Total number of states who scored more than national average in Math in 2018 is:
sat18_above_mean_math = df[df['2018_sat_math'] > df['2018_sat_math'].mean()].sort_values(by='2018_sat_math', ascending=False)
len(sat18_above_mean_math)
# Out:
# 19

# %%
# Visualizing the difference of mean, median and distribution of verbal score
plt.figure(figsize=(25,8))
sns.displot(df['2018_sat_ebrw'], bins=20)
plt.axvline(x=df['2018_sat_ebrw'].mean(), linewidth=2.5, linestyle='dashed', color='r', label='Average score')
plt.axvline(x=df['2018_sat_ebrw'].median(), linewidth=2.5, linestyle='dashed', color='g', label='Median score')
plt.legend()
plt.xlabel('Verbal Score', color='r')
plt.title('Distribution of Verbal score', size=16, color='blue')
plt.ylabel('Number of States', color='g');

# %%
df_corr = df.drop(columns=['state']).corr()
df_corr
# Out:
#                              2018_act_participation_rate  2018_act_composite  \
# 2018_act_participation_rate                     1.000000           -0.867196
# 2018_act_composite                             -0.867196            1.000000
# 2019_act_participation_rate                     0.989597           -0.855908
# 2019_act_composite                             -0.865724            0.991835
# 2018_sat_participation_rate                    -0.872051            0.763172
# 2018_sat_ebrw                                   0.598552           -0.404478
# 2018_sat_math                                   0.640150           -0.408743
# 2018_sat_total                                  0.626644           -0.411671
# 2019_sat_participation_rate                    -0.829212            0.688147
# 2019_sat_ebrw                                   0.656901           -0.424898
# 2019_sat_math                                   0.607676           -0.353056
# ...

# %%
#Corr

plt.figure(figsize=(10,6))
sns.heatmap(df_corr)
plt.title('2018 and 2019 SAT Score Correlation', size=14, color='blue')
# Out:
# Text(0.5, 1.0, '2018 and 2019 SAT Score Correlation')

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - Since the SAT/ACT requirements are on the verge of facing out, further analysis needs to be done with more comprehensive and advanced approach

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %% [markdown]
# ## Recommendations

# %% [markdown]
# - Based on the analysis, SAT mean score for math is less than the verbal test for both years.
#
# - SAT mean participation rate increased by more than 4% in 2019.
#
# - SAT score doesn’t reflect participation rate, and vice versa.
#
# - This analysis can’t help us infer whether SAT score is the best indication of student  success  after enrolling into a college.
#
#
# **Recomendation**
#
# > Since SAT requirement for college enrollment is currently suspended for many colleges, further comprehensive analysis needs to be conducted on students' high school performance.

# %% [markdown]
# ## References:
# * [Class Notes](https://git.generalassemb.ly/sileshith/dsir-111/blob/master/week-02/2.09-lesson-linear-regression/starter-code-SH.ipynb)
# * [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)
# * [SiewLin_Yap](https://siewlinyap.github.io/portfolio/project2-analysis-on-sat-test)
# * [a-oh](https://github.com/a-oh/project1-standardizedtesting/blob/master/starter-code.ipynb)
# * [Stackoverflow](https://stackoverflow.com/questions/51749208/plotting-two-histograms-from-a-pandas-dataframe-in-one-subplot-using-matplotlib)
# * [THE ULTIMATE TEST- Trends in SAt and ACT Participation, 2017-2018](https://www.eamonfleming.com/projects/sat-act.html)
