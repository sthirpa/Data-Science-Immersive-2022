# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests

# %% [markdown]
# ## 1. level.fyi salary data

# %% [markdown]
# ### Retrieve level.fyi salary data and save it as csv

# %%
# retrieve level.fyi salary data and save it as csv

# data = requests.get('https://www.levels.fyi/js/salaryData.json').json()

# df = pd.DataFrame(data)

# df.to_csv('../Data/level_fyi_salary.csv', index=False)

# df.head()

# %% [markdown]
# ### Load level.fyi salary data and take a quick look

# %%
# load salary data
df = pd.read_csv('../Data/level_fyi_salary.csv')
df.head()
# Out:
#             timestamp    company level                         title  \
# 0   6/7/2017 11:33:27     Oracle    L3               Product Manager
# 1  6/10/2017 17:11:29       eBay  SE 2             Software Engineer
# 2  6/11/2017 14:53:57     Amazon    L7               Product Manager
# 3  6/14/2017 21:22:25  Microsoft    64  Software Engineering Manager
# 4  6/16/2017 10:44:01     Amazon    L5             Software Engineer
#
#    totalyearlycompensation               location  yearsofexperience  \
# 0                    127.0       Redwood City, CA                1.5
# 1                    100.0      San Francisco, CA                5.0
# 2                    310.0            Seattle, WA                8.0
# 3                    200.0            Redmond, WA                9.0
# 4                    173.0  Vancouver, BC, Canada               11.0
#
#    yearsatcompany  tag  basesalary  stockgrantvalue    bonus gender  \
# 0             1.5  NaN       107.0             20.0     10.0    NaN
# 1             3.0  NaN         NaN              NaN      NaN    NaN
# 2             0.0  NaN       155.0              NaN      NaN    NaN
# 3             9.0  NaN    169000.0         100000.0  30000.0    NaN
# 4             1.0  NaN    120000.0              0.0  53000.0    NaN
#
#   otherdetails  cityid  dmaid  rowNumber
# 0          NaN    7392  807.0          1
# 1          NaN    7419  807.0          2
# 2          NaN   11527  819.0          3
# 3          NaN   11521  819.0          5
# 4          NaN    1320    0.0          6

# %%
df.shape
# Out:
# (62642, 17)

# %% [markdown]
# #### Work with missing data

# %%
df.isnull().sum()  # some columns have a lot of missing data
# Out:
# timestamp                      0
# company                        5
# level                        115
# title                          0
# totalyearlycompensation        0
# location                       0
# yearsofexperience              0
# yearsatcompany                 0
# tag                          854
# basesalary                  2304
# stockgrantvalue             2684
# bonus                       3988
# gender                     19540
# otherdetails               22505
# cityid                         0
# dmaid                          2
# rowNumber                      0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# timestamp                  0.000000
# company                    0.000080
# level                      0.001836
# title                      0.000000
# totalyearlycompensation    0.000000
# location                   0.000000
# yearsofexperience          0.000000
# yearsatcompany             0.000000
# tag                        0.013633
# basesalary                 0.036780
# stockgrantvalue            0.042847
# bonus                      0.063663
# gender                     0.311931
# otherdetails               0.359264
# cityid                     0.000000
# dmaid                      0.000032
# rowNumber                  0.000000
# dtype: float64

# %%
# explore how to deal with missing data

df1 = df.copy()
print(f'original data size: {df.shape}')

df1.replace({'':np.nan}, inplace=True)
print(f"data size after dropping all na's: {df1.dropna().shape}")
      
df2 = df.copy()
df2 = df2.drop(columns=['gender','otherdetails'])

df2.replace({'':np.nan}, inplace=True)
print(f"data size after dropping 2 columns and then dropping all na's: {df2.dropna().shape}")
# Out:
# original data size: (62642, 17)
# data size after dropping all na's: (29980, 17)
# data size after dropping 2 columns and then dropping all na's: (57910, 15)

# %%
# so the decision is to drop 2 columns (gender,otherdetails), and then drop na's
df.drop(columns=['gender','otherdetails'], inplace=True)
df.replace({'':np.nan}, inplace=True)
df.dropna(inplace=True)
df.shape
# Out:
# (57910, 15)

# %%
df.head()
# Out:
#              timestamp   company           level              title  \
# 725  6/3/2018 13:58:20     Yahoo             IC2  Software Engineer
# 726  6/3/2018 14:54:39       IBM  Staff Engineer  Software Engineer
# 731  6/4/2018 20:28:22  Facebook              E3  Software Engineer
# 732   6/5/2018 0:56:33    VmWare      Senior MTS  Software Engineer
# 733   6/5/2018 1:19:05      Uber              L4  Software Engineer
#
#      totalyearlycompensation                       location  \
# 725                    160.5                  Sunnyvale, CA
# 726                    120.0  Cambridge, EN, United Kingdom
# 731                    165.0                    Seattle, WA
# 732                    218.0                  Palo Alto, CA
# 733                    240.0              San Francisco, CA
#
#      yearsofexperience  yearsatcompany                             tag  \
# 725               0.58            0.58                      Full Stack
# 726               7.00            2.00  Distributed Systems (Back-End)
# 731               1.00            1.00                      Full Stack
# 732               8.00            1.00  Distributed Systems (Back-End)
# 733               3.00            0.00     Web Development (Front-End)
#
#      basesalary  stockgrantvalue    bonus  cityid  dmaid  rowNumber
# 725       128.0             13.0     19.2    7472  807.0        791
# 726    115000.0              0.0   5000.0    4878    0.0        792
# 731    114000.0          37500.0  11400.0   11527  819.0        799
# 732       165.0         100000.0  32000.0    7351  807.0        800
# 733    145000.0          81500.0  13500.0    7419  807.0        801

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62642 entries, 0 to 62641
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                62642 non-null  object
#  1   company                  62637 non-null  object
#  2   level                    62527 non-null  object
#  3   title                    62642 non-null  object
#  4   totalyearlycompensation  62642 non-null  float64
#  5   location                 62642 non-null  object
#  6   yearsofexperience        62642 non-null  float64
#  7   yearsatcompany           62642 non-null  float64
#  8   tag                      61788 non-null  object
#  9   basesalary               60338 non-null  float64
#  10  stockgrantvalue          59958 non-null  float64
#  11  bonus                    58654 non-null  float64
#  12  cityid                   62642 non-null  int64
#  13  dmaid                    62640 non-null  float64
#  14  rowNumber                62642 non-null  int64
# dtypes: float64(7), int64(2), object(6)
# memory usage: 7.2+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Explore on taking a subst of salary data

# %% [markdown]
# ##### Take a subset of companies

# %%
'''
print(len(df['company'].unique()))  # 1871 companies in total

df['company'].value_counts(normalize=True).head(50)
'''
# Out:
# "\nprint(len(df['company'].unique()))  # 1871 companies in total\n\ndf['company'].value_counts(normalize=True).head(50)\n"

# %%
# df['company'].value_counts(normalize=True).tail(20)

# %%
'''
company_df = pd.DataFrame(df['company'].value_counts(normalize=True))
company_df.rename(columns={'company':'prop'}, inplace=True)
company_df['prop_cum'] = company_df['prop'].cumsum()
company_df
'''
# Out:
# "\ncompany_df = pd.DataFrame(df['company'].value_counts(normalize=True))\ncompany_df.rename(columns={'company':'prop'}, inplace=True)\ncompany_df['prop_cum'] = company_df['prop'].cumsum()\ncompany_df\n"

# %%
# company_df.to_csv('../Data/company_list.csv')

# %%
'''
print(company_df.loc[company_df['prop_cum'] <=.60, :].shape)
company_df.loc[company_df['prop_cum'] <=.60, :]  # the top 33 companies count for 60% of the salary records

df.shape[0]*0.60  # the top 32 companies count for 60% of the salary records, which is 34,746 rows

print(company_df.loc[company_df['prop_cum'] <=.80, :].shape)  # the top 164 companies count for 80% of the records, which is 46,328 rows
df.shape[0]*0.80
'''
# Out:
# "\nprint(company_df.loc[company_df['prop_cum'] <=.60, :].shape)\ncompany_df.loc[company_df['prop_cum'] <=.60, :]  # the top 33 companies count for 60% of the salary records\n\ndf.shape[0]*0.60  # the top 32 companies count for 60% of the salary records, which is 34,746 rows\n\nprint(company_df.loc[company_df['prop_cum'] <=.80, :].shape)  # the top 164 companies count for 80% of the records, which is 46,328 rows\ndf.shape[0]*0.80\n"

# %% [markdown]
# ##### Take a subset of years

# %%
'''
# convert timestamp from string to datetime column
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp']

df['timestamp'].sort_values()  # 2018-06-03 13:58:20 to 2021-08-17 08:28:57

df['timestamp'].dt.year.value_counts().sort_index(ascending=False)

df['timestamp'].dt.year.value_counts(normalize=True).sort_index(ascending=False)
'''
# Out:
# "\n# convert timestamp from string to datetime column\ndf['timestamp'] = pd.to_datetime(df['timestamp'])\ndf['timestamp']\n\ndf['timestamp'].sort_values()  # 2018-06-03 13:58:20 to 2021-08-17 08:28:57\n\ndf['timestamp'].dt.year.value_counts().sort_index(ascending=False)\n\ndf['timestamp'].dt.year.value_counts(normalize=True).sort_index(ascending=False)\n"

# %%
# create year and month
df['timestamp'] = pd.to_datetime(df['timestamp'])

df['year'] = df['timestamp'].copy().dt.year
df['month'] = df['timestamp'].copy().dt.month
df.head()
# Out:
#               timestamp   company           level              title  \
# 725 2018-06-03 13:58:20     Yahoo             IC2  Software Engineer
# 726 2018-06-03 14:54:39       IBM  Staff Engineer  Software Engineer
# 731 2018-06-04 20:28:22  Facebook              E3  Software Engineer
# 732 2018-06-05 00:56:33    VmWare      Senior MTS  Software Engineer
# 733 2018-06-05 01:19:05      Uber              L4  Software Engineer
#
#      totalyearlycompensation                       location  \
# 725                    160.5                  Sunnyvale, CA
# 726                    120.0  Cambridge, EN, United Kingdom
# 731                    165.0                    Seattle, WA
# 732                    218.0                  Palo Alto, CA
# 733                    240.0              San Francisco, CA
#
#      yearsofexperience  yearsatcompany                             tag  \
# 725               0.58            0.58                      Full Stack
# 726               7.00            2.00  Distributed Systems (Back-End)
# 731               1.00            1.00                      Full Stack
# 732               8.00            1.00  Distributed Systems (Back-End)
# 733               3.00            0.00     Web Development (Front-End)
#
#      basesalary  stockgrantvalue    bonus  cityid  dmaid  rowNumber  year  \
# 725       128.0             13.0     19.2    7472  807.0        791  2018
# 726    115000.0              0.0   5000.0    4878    0.0        792  2018
# 731    114000.0          37500.0  11400.0   11527  819.0        799  2018
# 732       165.0         100000.0  32000.0    7351  807.0        800  2018
# 733    145000.0          81500.0  13500.0    7419  807.0        801  2018
#
#      month
# 725      6
# 726      6
# 731      6
# 732      6
# 733      6

# %%
pd.DataFrame(df['year'].value_counts()).sort_index(ascending=False)  # salary data are from 2018 to 2021
# pd.DataFrame(df[['year','month']].value_counts(normalize=True)).sort_index(ascending=False)  # salary data are from 2018 to 2021
# Out:
#        year
# 2021  23342
# 2020  23859
# 2019   8435
# 2018   2274

# %%
# create state
df['state'] = df['location'].apply(lambda x: x.split(',')[-1].strip())
df[['location','state']]
# Out:
#                             location           state
# 725                    Sunnyvale, CA              CA
# 726    Cambridge, EN, United Kingdom  United Kingdom
# 731                      Seattle, WA              WA
# 732                    Palo Alto, CA              CA
# 733                San Francisco, CA              CA
# ...                              ...             ...
# 62637                    Seattle, WA              WA
# 62638                     Durham, NC              NC
# 62639                   San Jose, CA              CA
# 62640                   New York, NY              NY
# 62641              San Francisco, CA              CA
#
# [57910 rows x 2 columns]

# %%
df['state'].value_counts().head(60)  # there are foreign countries in location
# Out:
# CA                      20846
# WA                      10914
# NY                       4420
# India                    2768
# TX                       2584
# Canada                   1703
# MA                       1612
# United Kingdom           1138
# VA                        878
# IL                        849
# OR                        600
# DC                        564
# Germany                   561
# GA                        558
# CO                        547
# NC                        483
# PA                        462
# NJ                        449
# Singapore                 369
# AZ                        368
# Taiwan                    302
# Ireland                   295
# FL                        284
# Israel                    279
# MN                        268
# Australia                 240
# Russia                    239
# Netherlands               238
# UT                        219
# MI                        210
# OH                        190
# MO                        181
# Switzerland               176
# WI                        146
# MD                        100
# CT                        100
# Spain                      96
# Japan                      96
# IN                         92
# China                      92
# AR                         86
# Poland                     77
# TN                         77
# France                     70
# Ukraine                    62
# DE                         56
# Sweden                     46
# ID                         44
# Czech Republic             42
# Brazil                     38
# KS                         37
# Luxembourg                 37
# Hong Kong (SAR)            31
# LA                         30
# NH                         30
# IA                         28
# United Arab Emirates       26
# Romania                    25
# NE                         24
# Indonesia                  24
# Name: state, dtype: int64

# %%
'Cambridge, EN, United Kingdom'.split(',')[-1].strip()
# Out:
# 'United Kingdom'

# %%
df.to_csv('../Data/salary_noNA.csv', index=False)

# %% [markdown]
# ## 2. Alpha Advantage: Company Overview
# - Symbol
# - Sector
# - Industry
# - Address

# %%
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Symbol': 'IBM', 'AssetType': 'Common Stock', 'Name': 'International Business Machines Corporation', 'Description': 'International Business Machines Corporation (IBM) is an American multinational technology company headquartered in Armonk, New York, with operations in over 170 countries. The company began in 1911, founded in Endicott, New York, as the Computing-Tabulating-Recording Company (CTR) and was renamed International Business Machines in 1924. IBM is incorporated in New York. IBM produces and sells computer hardware, middleware and software, and provides hosting and consulting services in areas ranging from mainframe computers to nanotechnology. IBM is also a major research organization, holding the record for most annual U.S. patents generated by a business (as of 2020) for 28 consecutive years. Inventions by IBM include the automated teller machine (ATM), the floppy disk, the hard disk drive, the magnetic stripe card, the relational database, the SQL programming language, the UPC barcode, and dynamic random-access memory (DRAM). The IBM mainframe, exemplified by the System/360, was the dominant computing platform during the 1960s and 1970s.', 'CIK': '51143', 'Exchange': 'NYSE', 'Currency': 'USD', 'Country': 'USA', 'Sector': 'TECHNOLOGY', 'Industry': 'COMPUTER & OFFICE EQUIPMENT', 'Address': '1 NEW ORCHARD ROAD, ARMONK, NY, US', 'FiscalYearEnd': 'December', 'LatestQuarter': '2021-09-30', 'MarketCapitalization': '119524278000', 'EBITDA': '15659000000', 'PERatio': '25.24', 'PEGRatio': '2.154', 'BookValue': '24.79', 'DividendPerShare': '6.54', 'DividendYield': '0.0493', 'EPS': '5.28', 'RevenuePerShareTTM': '83.23', 'ProfitMargin': '0.064', 'OperatingMarginTTM': '0.12', 'ReturnOnAssetsTTM': '0.0374', 'ReturnOnEquityTTM': '0.214', 'RevenueTTM': '74461004000', 'GrossProfitTTM': '35575000000', 'DilutedEPSTTM': '5.28', 'QuarterlyEarningsGrowthYOY': '-0.338', 'QuarterlyRevenueGrowthYOY': '0.003', 'AnalystTargetPrice': '145.17', 'TrailingPE': '25.24', 'ForwardPE': '10.86', 'PriceToSalesRatioTTM': '1.605', 'PriceToBookRatio': '5.01', 'EVToRevenue': '2.178', 'EVToEBITDA': '12.51', 'Beta': '1.104', '52WeekHigh': '142.43', '52WeekLow': '106.73', '50DayMovingAverage': '122.51', '200DayMovingAverage': '131.54', 'SharesOutstanding': '896320000', 'DividendDate': '2021-12-10', 'ExDividendDate': '2021-11-09'}

# %%
# key = 'your_personal_key' # put your key here

def get_company_alpha_advantage(companies, function):
    mylist = []
    for company in companies:
        base = 'https://www.alphavantage.co/query?'
        result = requests.get(url = base,
                             params = {
                                 'function':function,
                                 'symbol':company,
                                 'apikey':key
                             })
        data = result.json()
        mylist.append(data)
    return mylist

# %%
companies = ['IBM','AMZN','AApl']
function = 'OVERVIEW'

data = get_company_alpha_advantage(companies, function)

# %%
overview = pd.DataFrame(data)
overview
# Out:
#   Symbol     AssetType                                         Name  \
# 0    IBM  Common Stock  International Business Machines Corporation
# 1   AMZN  Common Stock                               Amazon.com Inc
# 2   AAPL  Common Stock                                    Apple Inc
#
#                                          Description      CIK Exchange  \
# 0  International Business Machines Corporation (I...    51143     NYSE
# 1  Amazon.com, Inc. is an American multinational ...  1018724   NASDAQ
# 2  Apple Inc. is an American multinational techno...   320193   NASDAQ
#
#   Currency Country            Sector                            Industry  ...  \
# 0      USD     USA        TECHNOLOGY         COMPUTER & OFFICE EQUIPMENT  ...
# 1      USD     USA  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES  ...
# 2      USD     USA        TECHNOLOGY                ELECTRONIC COMPUTERS  ...
#
#   EVToRevenue EVToEBITDA   Beta 52WeekHigh 52WeekLow 50DayMovingAverage  \
# 0       2.178      12.51  1.104     142.43    106.73             122.51
# 1        3.89      27.48  1.126    3773.08      2881            3458.85
# 2        8.22      24.41  1.203     182.13    115.67             160.29
#
#   200DayMovingAverage SharesOutstanding DividendDate ExDividendDate
# 0              131.54         896320000   2021-12-10     2021-11-09
# 1             3380.84         507148000         None           None
# 2              143.13       16406400000   2021-11-11     2021-11-05
#
# [3 rows x 46 columns]

# %%
# https://stackoverflow.com/questions/19726029/how-can-i-make-pandas-dataframe-column-headers-all-lowercase

overview = overview[['Symbol','Sector','Industry','Address']]
overview.columns = map(str.lower, overview.columns)  
overview
# Out:
#   symbol            sector                            industry  \
# 0    IBM        TECHNOLOGY         COMPUTER & OFFICE EQUIPMENT
# 1   AMZN  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 2   AAPL        TECHNOLOGY                ELECTRONIC COMPUTERS
#
#                                    address
# 0       1 NEW ORCHARD ROAD, ARMONK, NY, US
# 1  410 TERRY AVENUE NORTH, SEATTLE, WA, US
# 2     ONE INFINITE LOOP, CUPERTINO, CA, US

# %%
overview.to_csv('../Data/overview.csv', index=False)

# %% [markdown]
# ### 3. Alpha Advantage: Inflation (annual)

# %%
# key = 'your_personal_key' # put your key here

url = 'https://www.alphavantage.co/query?function=INFLATION&apikey='+key

r = requests.get(url)
data = r.json()

inflation = pd.DataFrame(data['data'])
inflation
# Out:
#           date             value
# 0   2020-01-01  1.23358439630637
# 1   2019-01-01  1.81221007526015
# 2   2018-01-01  2.44258329692818
# 3   2017-01-01  2.13011000365963
# 4   2016-01-01  1.26158320570537
# ..         ...               ...
# 56  1964-01-01  1.27891156462583
# 57  1963-01-01   1.2396694214876
# 58  1962-01-01  1.19877334820185
# 59  1961-01-01  1.07072414764723
# 60  1960-01-01  1.45797598627786
#
# [61 rows x 2 columns]

# %%
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    61 non-null     object
#  1   value   61 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
inflation['date'] = pd.to_datetime(inflation['date'])

inflation['value'] = inflation['value'].astype(float)

inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    61 non-null     datetime64[ns]
#  1   value   61 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB

# %%
inflation['year'] = inflation['date'].copy().dt.year

inflation['month'] = inflation['date'].copy().dt.month

inflation.head()
# Out:
#         date     value  year  month
# 0 2020-01-01  1.233584  2020      1
# 1 2019-01-01  1.812210  2019      1
# 2 2018-01-01  2.442583  2018      1
# 3 2017-01-01  2.130110  2017      1
# 4 2016-01-01  1.261583  2016      1

# %%
inflation.to_csv('../Data/inflation.csv', index=False)

# %%
test = pd.read_csv('../Data/inflation.csv')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    61 non-null     object
#  1   value   61 non-null     float64
#  2   year    61 non-null     int64
#  3   month   61 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# ### 4. Alpha Advantage: Unemployment rate (monthly)

# %%
# key = 'your_personal_key' # put your key here

url = 'https://www.alphavantage.co/query?function=UNEMPLOYMENT&apikey='+key
r = requests.get(url)
data = r.json()

unemp = pd.DataFrame(data['data'])
unemp
# Out:
#            date value
# 0    2021-11-01   4.2
# 1    2021-10-01   4.6
# 2    2021-09-01   4.8
# 3    2021-08-01   5.2
# 4    2021-07-01   5.4
# ..          ...   ...
# 882  1948-05-01   3.5
# 883  1948-04-01   3.9
# 884  1948-03-01   4.0
# 885  1948-02-01   3.8
# 886  1948-01-01   3.4
#
# [887 rows x 2 columns]

# %%
unemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    887 non-null    object
#  1   value   887 non-null    object
# dtypes: object(2)
# memory usage: 14.0+ KB

# %%
unemp['date'] = pd.to_datetime(unemp['date'])

unemp['value'] = unemp['value'].astype(float)

unemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    887 non-null    datetime64[ns]
#  1   value   887 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.0 KB

# %%
unemp['year'] = unemp['date'].copy().dt.year

# %%
unemp['month'] = unemp['date'].copy().dt.month

# %%
unemp.rename(columns={'value':'unemp_rate'}, inplace=True)

# %%
unemp.head()
# Out:
#          date  unemp_rate  year  month
# 0  2021-11-01         4.2  2021     11
# 1  2021-10-01         4.6  2021     10
# 2  2021-09-01         4.8  2021      9
# 3  2021-08-01         5.2  2021      8
# 4  2021-07-01         5.4  2021      7

# %%
unemp.to_csv('../Data/unemployment.csv', index=False)

# %% [markdown]
# ### 5. Data World: Employment / unemployment counts monthly by state 1/1976-9/2020

# %% [markdown]
# Employment & Unemployment by State and Month - dataset by vizwiz
#
# https://data.world/vizwiz/employment-unemployment-by-state-and-month/workspace/file?filename=BLS+Monthly+Unemployment+Rate.xlsx

# %%
employ =

# %%
# Load mapping of state names to state abbreviation

import json

with open('https://gist.githubusercontent.com/AnnieW2014/d5c59b029307cce0e18cf7bf2dd0f93b/raw/6591f2de775a139fa6f31b4e3d991e12133be9d6/us_state_abbrev.py') as f:
    data = f.read()
    
print("Data type before reconstruction : ", type(data))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-1f707162afe9> in <module>
#       3 import json
#       4
# ----> 5 with open('https://gist.githubusercontent.com/AnnieW2014/d5c59b029307cce0e18cf7bf2dd0f93b/raw/6591f2de775a139fa6f31b4e3d991e12133be9d6/us_state_abbrev.py') as f:
#       6     data = f.read()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://gist.githubusercontent.com/AnnieW2014/d5c59b029307cce0e18cf7bf2dd0f93b/raw/6591f2de775a139fa6f31b4e3d991e12133be9d6/us_state_abbrev.py'

# %%
# reconstructing the data as a dictionary
js = json.loads(data)
  
print("Data type after reconstruction : ", type(js))
print(js)

# %%
state_mapping = pd.read_csv('https://gist.githubusercontent.com/AnnieW2014/d5c59b029307cce0e18cf7bf2dd0f93b/raw/6591f2de775a139fa6f31b4e3d991e12133be9d6/us_state_abbrev.py')
state_mapping

# %% [markdown]
# ### 5. Merge all datasets together

# %% [markdown]
# #### Load salary data, create year and month from timestamp, and state from location

# %%
# load salary data
salary = pd.read_csv('../Data/salary_noNA.csv')
print(salary.shape)

salary.head()
# Out:
# (57910, 15)
#              timestamp   company           level              title  \
# 0  2018-06-03 13:58:20     Yahoo             IC2  Software Engineer
# 1  2018-06-03 14:54:39       IBM  Staff Engineer  Software Engineer
# 2  2018-06-04 20:28:22  Facebook              E3  Software Engineer
# 3  2018-06-05 00:56:33    VmWare      Senior MTS  Software Engineer
# 4  2018-06-05 01:19:05      Uber              L4  Software Engineer
#
#    totalyearlycompensation                       location  yearsofexperience  \
# 0                    160.5                  Sunnyvale, CA               0.58
# 1                    120.0  Cambridge, EN, United Kingdom               7.00
# 2                    165.0                    Seattle, WA               1.00
# 3                    218.0                  Palo Alto, CA               8.00
# 4                    240.0              San Francisco, CA               3.00
#
#    yearsatcompany                             tag  basesalary  \
# 0            0.58                      Full Stack       128.0
# 1            2.00  Distributed Systems (Back-End)    115000.0
# 2            1.00                      Full Stack    114000.0
# 3            1.00  Distributed Systems (Back-End)       165.0
# 4            0.00     Web Development (Front-End)    145000.0
#
#    stockgrantvalue    bonus  cityid  dmaid  rowNumber
# 0             13.0     19.2    7472  807.0        791
# 1              0.0   5000.0    4878    0.0        792
# 2          37500.0  11400.0   11527  819.0        799
# 3         100000.0  32000.0    7351  807.0        800
# 4          81500.0  13500.0    7419  807.0        801

# %%
salary['timestamp'] = pd.to_datetime(salary['timestamp'])
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57910 entries, 0 to 57909
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                57910 non-null  datetime64[ns]
#  1   company                  57910 non-null  object
#  2   level                    57910 non-null  object
#  3   title                    57910 non-null  object
#  4   totalyearlycompensation  57910 non-null  float64
#  5   location                 57910 non-null  object
#  6   yearsofexperience        57910 non-null  float64
#  7   yearsatcompany           57910 non-null  float64
#  8   tag                      57910 non-null  object
#  9   basesalary               57910 non-null  float64
#  10  stockgrantvalue          57910 non-null  float64
#  11  bonus                    57910 non-null  float64
#  12  cityid                   57910 non-null  int64
#  13  dmaid                    57910 non-null  float64
#  14  rowNumber                57910 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(5)
# memory usage: 6.6+ MB

# %%
'''
# create salary_year and salary_month
salary['year'] = salary['timestamp'].copy().dt.year
salary['month'] = salary['timestamp'].copy().dt.month
salary.head()
'''
# Out:
#             timestamp   company           level              title  \
# 0 2018-06-03 13:58:20     Yahoo             IC2  Software Engineer
# 1 2018-06-03 14:54:39       IBM  Staff Engineer  Software Engineer
# 2 2018-06-04 20:28:22  Facebook              E3  Software Engineer
# 3 2018-06-05 00:56:33    VmWare      Senior MTS  Software Engineer
# 4 2018-06-05 01:19:05      Uber              L4  Software Engineer
#
#    totalyearlycompensation                       location  yearsofexperience  \
# 0                    160.5                  Sunnyvale, CA               0.58
# 1                    120.0  Cambridge, EN, United Kingdom               7.00
# 2                    165.0                    Seattle, WA               1.00
# 3                    218.0                  Palo Alto, CA               8.00
# 4                    240.0              San Francisco, CA               3.00
#
#    yearsatcompany                             tag  basesalary  \
# 0            0.58                      Full Stack       128.0
# 1            2.00  Distributed Systems (Back-End)    115000.0
# 2            1.00                      Full Stack    114000.0
# 3            1.00  Distributed Systems (Back-End)       165.0
# 4            0.00     Web Development (Front-End)    145000.0
#
#    stockgrantvalue    bonus  cityid  dmaid  rowNumber  year  month
# 0             13.0     19.2    7472  807.0        791  2018      6
# 1              0.0   5000.0    4878    0.0        792  2018      6
# 2          37500.0  11400.0   11527  819.0        799  2018      6
# 3         100000.0  32000.0    7351  807.0        800  2018      6
# 4          81500.0  13500.0    7419  807.0        801  2018      6

# %%
# Out:
#   File "<ipython-input-33-1255f8bca4b9>", line 2
#     salary['salary_state'] = salary['location'].
#                                                 ^
# SyntaxError: invalid syntax

# %%
# load inflation (annual)
inflation = pd.read_csv('Data/inflation.csv')
inflation.head()
# Out:
#          date     value  year  month
# 0  2020-01-01  1.233584  2020      1
# 1  2019-01-01  1.812210  2019      1
# 2  2018-01-01  2.442583  2018      1
# 3  2017-01-01  2.130110  2017      1
# 4  2016-01-01  1.261583  2016      1

# %%
# load unemployment rate (monthly)
unemp = pd.read_csv('Data/unemployment.csv')
unemp.head()
# Out:
#          date  value  year  month
# 0  2021-11-01    4.2  2021     11
# 1  2021-10-01    4.6  2021     10
# 2  2021-09-01    4.8  2021      9
# 3  2021-08-01    5.2  2021      8
# 4  2021-07-01    5.4  2021      7

# %%
# merge salary and company_list_AW
final = pd.merge(left=salary, right=company[['company','symbol']], on='company',
                how='inner')
final.loc[final['company']=='Amazon', :].head()
# Out:
#                 timestamp company level                         title  \
# 19551 2018-06-08 06:40:35  Amazon    L5             Software Engineer
# 19552 2018-06-09 21:24:59  Amazon    L6  Software Engineering Manager
# 19553 2018-06-10 20:23:37  Amazon    L4             Software Engineer
# 19554 2018-06-13 18:59:55  Amazon    L5             Software Engineer
# 19555 2018-06-15 22:48:07  Amazon    L5             Software Engineer
#
#        totalyearlycompensation               location  yearsofexperience  \
# 19551                    210.0             Boston, MA               12.0
# 19552                    319.0            Seattle, WA                6.0
# 19553                    135.0            Seattle, WA                2.0
# 19554                    202.0            Seattle, WA                2.5
# 19555                    160.0  Vancouver, BC, Canada               10.0
#
#        yearsatcompany                             tag  basesalary  \
# 19551             4.0  Distributed Systems (Back-End)       143.0
# 19552             1.0                          DevOps    140000.0
# 19553             0.0      API Development (Back-End)       105.0
# 19554             0.0  Distributed Systems (Back-End)    140000.0
# 19555             1.0                      Full Stack       130.0
#
#        stockgrantvalue     bonus  cityid  dmaid  rowNumber  salary_year  \
# 19551            180.0      30.0    8816  506.0        847         2018
# 19552         380000.0  280000.0   11527  819.0        866         2018
# 19553              5.0      25.0   11527  819.0        872         2018
# 19554         150000.0  110000.0   11527  819.0        904         2018
# 19555              0.0      30.0    1320    0.0        929         2018
#
#        salary_month symbol
# 19551             6   AMZN
# 19552             6   AMZN
# 19553             6   AMZN
# 19554             6   AMZN
# 19555             6   AMZN

# %%
# merge in company overview
final = pd.merge(left=final, right=overview, on='symbol',
                how='left')
final.loc[final['company']=='Amazon', :].head()
# Out:
#                 timestamp company level                         title  \
# 19551 2018-06-08 06:40:35  Amazon    L5             Software Engineer
# 19552 2018-06-09 21:24:59  Amazon    L6  Software Engineering Manager
# 19553 2018-06-10 20:23:37  Amazon    L4             Software Engineer
# 19554 2018-06-13 18:59:55  Amazon    L5             Software Engineer
# 19555 2018-06-15 22:48:07  Amazon    L5             Software Engineer
#
#        totalyearlycompensation               location  yearsofexperience  \
# 19551                    210.0             Boston, MA               12.0
# 19552                    319.0            Seattle, WA                6.0
# 19553                    135.0            Seattle, WA                2.0
# 19554                    202.0            Seattle, WA                2.5
# 19555                    160.0  Vancouver, BC, Canada               10.0
#
#        yearsatcompany                             tag  basesalary  ...  \
# 19551             4.0  Distributed Systems (Back-End)       143.0  ...
# 19552             1.0                          DevOps    140000.0  ...
# 19553             0.0      API Development (Back-End)       105.0  ...
# 19554             0.0  Distributed Systems (Back-End)    140000.0  ...
# 19555             1.0                      Full Stack       130.0  ...
#
#           bonus  cityid  dmaid  rowNumber  salary_year  salary_month  symbol  \
# 19551      30.0    8816  506.0        847         2018             6    AMZN
# 19552  280000.0   11527  819.0        866         2018             6    AMZN
# 19553      25.0   11527  819.0        872         2018             6    AMZN
# 19554  110000.0   11527  819.0        904         2018             6    AMZN
# 19555      30.0    1320    0.0        929         2018             6    AMZN
#
#                  sector                            industry  \
# 19551  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 19552  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 19553  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 19554  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 19555  TRADE & SERVICES  RETAIL-CATALOG & MAIL-ORDER HOUSES
#
#                                        address
# 19551  410 TERRY AVENUE NORTH, SEATTLE, WA, US
# 19552  410 TERRY AVENUE NORTH, SEATTLE, WA, US
# 19553  410 TERRY AVENUE NORTH, SEATTLE, WA, US
# 19554  410 TERRY AVENUE NORTH, SEATTLE, WA, US
# 19555  410 TERRY AVENUE NORTH, SEATTLE, WA, US
#
# [5 rows x 21 columns]

# %%
# merge in inflation - need to clean up!!!
test = pd.merge(left=final, right=inflation,
                left_on=['salary_year','salary_month'], right_on=['year','month'],
                how='left')
test.loc[(test['company']=='Amazon') & (test['year']==2020), :].head()
# Out:
#                 timestamp company       level              title  \
# 20634 2020-01-01 11:44:06  Amazon          L5  Software Engineer
# 20635 2020-01-01 17:30:42  Amazon          L7     Data Scientist
# 20636 2020-01-01 18:03:18  Amazon          L7    Product Manager
# 20637 2020-01-01 18:47:43  Amazon  Senior SDE  Software Engineer
# 20638 2020-01-01 22:59:12  Amazon          L4  Software Engineer
#
#        totalyearlycompensation     location  yearsofexperience  \
# 20634                    244.0  Seattle, WA                6.0
# 20635                    500.0  Seattle, WA                9.0
# 20636                    320.0  Seattle, WA               10.0
# 20637                    271.0  Seattle, WA                8.0
# 20638                    144.0  Seattle, WA                4.0
#
#        yearsatcompany                             tag  basesalary  ...  \
# 20634             6.0      API Development (Back-End)       129.0  ...
# 20635             5.0                      Networking       180.0  ...
# 20636             5.0                         ML / AI       150.0  ...
# 20637             4.0                      Full Stack       160.0  ...
# 20638             0.0  Distributed Systems (Back-End)       110.0  ...
#
#        salary_year  salary_month  symbol            sector  \
# 20634         2020             1    AMZN  TRADE & SERVICES
# 20635         2020             1    AMZN  TRADE & SERVICES
# 20636         2020             1    AMZN  TRADE & SERVICES
# 20637         2020             1    AMZN  TRADE & SERVICES
# 20638         2020             1    AMZN  TRADE & SERVICES
#
#                                  industry  \
# 20634  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 20635  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 20636  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 20637  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 20638  RETAIL-CATALOG & MAIL-ORDER HOUSES
#
#                                        address        date     value    year  \
# 20634  410 TERRY AVENUE NORTH, SEATTLE, WA, US  2020-01-01  1.233584  2020.0
# 20635  410 TERRY AVENUE NORTH, SEATTLE, WA, US  2020-01-01  1.233584  2020.0
# 20636  410 TERRY AVENUE NORTH, SEATTLE, WA, US  2020-01-01  1.233584  2020.0
# 20637  410 TERRY AVENUE NORTH, SEATTLE, WA, US  2020-01-01  1.233584  2020.0
# 20638  410 TERRY AVENUE NORTH, SEATTLE, WA, US  2020-01-01  1.233584  2020.0
#
#       month
# 20634   1.0
# 20635   1.0
# 20636   1.0
# 20637   1.0
# 20638   1.0
#
# [5 rows x 25 columns]
